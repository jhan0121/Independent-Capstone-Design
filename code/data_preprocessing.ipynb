# %%
import pandas as pd
from ydata_profiling import ProfileReport
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
matplotlib.use('Qt5Agg')
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False
import seaborn as sns

from sklearn.impute import KNNImputer

# %%
file_path = ['hn19_all_raw.csv', 'hn20_all_raw.csv', 'hn21_all_raw.csv']
df_19 = pd.read_csv("../data/" + file_path[0], encoding='UTF-8', low_memory=False)
df_20 = pd.read_csv("../data/" + file_path[1], encoding='UTF-8', low_memory=False)
df_21 = pd.read_csv("../data/" + file_path[2], encoding='UTF-8', low_memory=False)

df = pd.concat([df_19, df_20, df_21])

# %%
def see(a):
    i = df[a].isnull().sum()
    k = df[a].value_counts()
    print("nullity: ", end='')
    print(i)
    print("\n---")
    df[a].info()
    print("\n---")
    print(k)

# %%
df.shape
# Out:
# (22559, 976)

# %%
col = [
    'sex',
    'age',
    'DI2_dg',
    'DI2_2',
    'DI3_dg',
    'DI5_dg',
    'DE1_dg',
    'DE1_31',
    'DE1_32',
    'HE_glu',
    'HE_HbA1c',
    'BD1_11',
    'BD2_1',
    'sm_presnt',
    'BE3_31',
    'BE3_32',
    'BE3_33',
    'HE_DMfh1',
    'HE_DMfh2',
    'HE_HP',
    'HE_ht',
    'HE_wt',
    'HE_wc',
    'HE_BMI',
    'HE_obe',
    'HE_HCHOL',
    'HE_HTG',
    'N_EN',
    'N_PROT',
    'N_FAT',
    'N_CHO',
    'HE_insulin',
    'HE_Uglu'
]

col_female = [
    'LW_pr_1'
]

# HE_insulin: 인슐린
# HE_Uglu: 요당
# DI2_dg: 이상지질혈증 의사진단 여부
# DI2_2: 이상지질혈증 약복용
# DI3_dg: 뇌졸중 의사진단 여부
# DI5_dg: 심근경색증 의사진단 여부
# DE1_dg: 당뇨병 의사진단 여부
# DE1_31: 인슐린 주사
# DE1_32: 당뇨병약 
# HE_glu: 공복혈당
# HE_HbA1c: 당화혈색소
# BD1_11: 1년간 음주빈도
# BD2_1: 한 번에 마시는 음주량
# sm_presnt: 현재흡연율
# BE3_31: 1주일간 걷기 일수
# BE3_32: 걷기 지속 시간(시간)
# BE3_33: 걷기 지속 시간(분)
# LW_pr_1: (만15세이상) 임신횟수
# HE_DMfh1: 당뇨병 의사진단 여부(부)
# HE_DMfh2: 당뇨병 의사진단 여부(모)
# HE_HP: 고혈압 유병여부(19세이상)
# HE_ht: 신장
# HE_wt: 체중
# HE_wc: 허리둘레
# HE_BMI: 체질량지수
# HE_obe: 비만 유병여부(19세이상)
# HE_HCHOL: 고콜레스테롤혈증 유병여부(19세이상)
# HE_HTG: 고중성지방혈증 유병여부(19세이상)
# Y_BTH_WT: 출생 시 체중
# N_EN: 에너지
# N_PROT: 단백질
# N_FAT: 지방
# N_CHO: 탄수화물

# %%
df = df[df['age'] >= 20]
df = df[col]

# %%
df.shape
# Out:
# (18511, 33)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18511 entries, 0 to 7087
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   sex         18511 non-null  int64
#  1   age         18511 non-null  int64
#  2   DI2_dg      17731 non-null  float64
#  3   DI2_2       17731 non-null  float64
#  4   DI3_dg      17731 non-null  float64
#  5   DI5_dg      17731 non-null  float64
#  6   DE1_dg      17731 non-null  float64
#  7   DE1_31      17731 non-null  float64
#  8   DE1_32      17731 non-null  float64
#  9   HE_glu      17283 non-null  float64
#  10  HE_HbA1c    17276 non-null  float64
#  11  BD1_11      17731 non-null  float64
#  12  BD2_1       17731 non-null  float64
#  13  sm_presnt   17511 non-null  float64
#  14  BE3_31      17731 non-null  float64
#  15  BE3_32      17731 non-null  float64
#  16  BE3_33      17731 non-null  float64
#  17  HE_DMfh1    17635 non-null  float64
#  18  HE_DMfh2    17635 non-null  float64
#  19  HE_HP       17497 non-null  float64
#  20  HE_ht       17504 non-null  float64
#  21  HE_wt       17659 non-null  float64
#  22  HE_wc       17600 non-null  float64
#  23  HE_BMI      17493 non-null  float64
#  24  HE_obe      17454 non-null  float64
#  25  HE_HCHOL    16760 non-null  float64
#  26  HE_HTG      14540 non-null  float64
#  27  N_EN        15407 non-null  float64
#  28  N_PROT      15407 non-null  float64
#  29  N_FAT       15407 non-null  float64
#  30  N_CHO       15407 non-null  float64
#  31  HE_insulin  17277 non-null  float64
#  32  HE_Uglu     17098 non-null  float64
# dtypes: float64(31), int64(2)
# memory usage: 4.8 MB

# %%
df = df.copy()
df = df.apply(pd.to_numeric)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18511 entries, 0 to 7087
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   sex         18511 non-null  int64
#  1   age         18511 non-null  int64
#  2   DI2_dg      17731 non-null  float64
#  3   DI2_2       17731 non-null  float64
#  4   DI3_dg      17731 non-null  float64
#  5   DI5_dg      17731 non-null  float64
#  6   DE1_dg      17731 non-null  float64
#  7   DE1_31      17731 non-null  float64
#  8   DE1_32      17731 non-null  float64
#  9   HE_glu      17283 non-null  float64
#  10  HE_HbA1c    17276 non-null  float64
#  11  BD1_11      17731 non-null  float64
#  12  BD2_1       17731 non-null  float64
#  13  sm_presnt   17511 non-null  float64
#  14  BE3_31      17731 non-null  float64
#  15  BE3_32      17731 non-null  float64
#  16  BE3_33      17731 non-null  float64
#  17  HE_DMfh1    17635 non-null  float64
#  18  HE_DMfh2    17635 non-null  float64
#  19  HE_HP       17497 non-null  float64
#  20  HE_ht       17504 non-null  float64
#  21  HE_wt       17659 non-null  float64
#  22  HE_wc       17600 non-null  float64
#  23  HE_BMI      17493 non-null  float64
#  24  HE_obe      17454 non-null  float64
#  25  HE_HCHOL    16760 non-null  float64
#  26  HE_HTG      14540 non-null  float64
#  27  N_EN        15407 non-null  float64
#  28  N_PROT      15407 non-null  float64
#  29  N_FAT       15407 non-null  float64
#  30  N_CHO       15407 non-null  float64
#  31  HE_insulin  17277 non-null  float64
#  32  HE_Uglu     17098 non-null  float64
# dtypes: float64(31), int64(2)
# memory usage: 4.8 MB

# %%
df.head()
# Out:
#    sex  age  DI2_dg  DI2_2  DI3_dg  DI5_dg  DE1_dg  DE1_31  DE1_32  HE_glu  \
# 0    1   61     0.0    8.0     0.0     0.0     0.0     8.0     8.0   136.0
# 1    1   28     0.0    8.0     0.0     0.0     0.0     8.0     8.0    81.0
# 2    1   53     0.0    8.0     0.0     0.0     0.0     8.0     8.0    90.0
# 3    2   50     0.0    8.0     0.0     0.0     0.0     8.0     8.0    93.0
# 5    2   71     0.0    8.0     0.0     0.0     0.0     8.0     8.0   105.0
#
#    ...     HE_BMI  HE_obe  HE_HCHOL  HE_HTG         N_EN     N_PROT  \
# 0  ...  25.987394     4.0       0.0     0.0          NaN        NaN
# 1  ...  16.900942     1.0       0.0     0.0          NaN        NaN
# 2  ...  19.781829     2.0       0.0     0.0  1794.462141  73.011520
# 3  ...  26.631647     4.0       0.0     0.0  1921.973206  82.134681
# 5  ...  29.312416     4.0       0.0     0.0  1948.473145  81.044523
#
#        N_FAT       N_CHO  HE_insulin  HE_Uglu
# 0        NaN         NaN        10.4      4.0
# 1        NaN         NaN         2.3      0.0
# 2  33.617174  295.234107         1.4      0.0
# 3  60.321382  258.768545         6.6      0.0
# 5  68.819501  255.163743         5.0      0.0
#
# [5 rows x 33 columns]

# %%
target_list = ['DE1_31','DE1_32','DE1_dg', 'HE_glu', 'HE_HbA1c']
target_df = df[target_list]
target_df.head()
print(target_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18511 entries, 0 to 7087
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   DE1_31    17731 non-null  float64
#  1   DE1_32    17731 non-null  float64
#  2   DE1_dg    17731 non-null  float64
#  3   HE_glu    17283 non-null  float64
#  4   HE_HbA1c  17276 non-null  float64
# dtypes: float64(5)
# memory usage: 867.7 KB
# None

# %%
# null 값이 있는 행 삭제
df = df.dropna(subset=target_list)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17272 entries, 0 to 7087
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   sex         17272 non-null  int64
#  1   age         17272 non-null  int64
#  2   DI2_dg      17272 non-null  float64
#  3   DI2_2       17272 non-null  float64
#  4   DI3_dg      17272 non-null  float64
#  5   DI5_dg      17272 non-null  float64
#  6   DE1_dg      17272 non-null  float64
#  7   DE1_31      17272 non-null  float64
#  8   DE1_32      17272 non-null  float64
#  9   HE_glu      17272 non-null  float64
#  10  HE_HbA1c    17272 non-null  float64
#  11  BD1_11      17272 non-null  float64
#  12  BD2_1       17272 non-null  float64
#  13  sm_presnt   17088 non-null  float64
#  14  BE3_31      17272 non-null  float64
#  15  BE3_32      17272 non-null  float64
#  16  BE3_33      17272 non-null  float64
#  17  HE_DMfh1    17196 non-null  float64
#  18  HE_DMfh2    17196 non-null  float64
#  19  HE_HP       17081 non-null  float64
#  20  HE_ht       17073 non-null  float64
#  21  HE_wt       17212 non-null  float64
#  22  HE_wc       17161 non-null  float64
#  23  HE_BMI      17063 non-null  float64
#  24  HE_obe      17030 non-null  float64
#  25  HE_HCHOL    16754 non-null  float64
#  26  HE_HTG      14532 non-null  float64
#  27  N_EN        14309 non-null  float64
#  28  N_PROT      14309 non-null  float64
#  29  N_FAT       14309 non-null  float64
#  30  N_CHO       14309 non-null  float64
#  31  HE_insulin  17266 non-null  float64
#  32  HE_Uglu     16785 non-null  float64
# dtypes: float64(31), int64(2)
# memory usage: 4.5 MB

# %%
see('HE_insulin')
# Out:
# nullity: 6
#
# ---
# <class 'pandas.core.series.Series'>
# Index: 17272 entries, 0 to 7087
# Series name: HE_insulin
# Non-Null Count  Dtype
# --------------  -----
# 17266 non-null  float64
# dtypes: float64(1)
# memory usage: 269.9 KB
#
# ---
# HE_insulin
# 5.6      209
# 5.3      205
# 6.1      204
# 4.9      202
# 6.3      201
#         ...
# 86.9       1
# 136.0      1
# 39.3       1
# 45.4       1
# 30.5       1
# Name: count, Length: 526, dtype: int64

# %%
see('HE_Uglu')
# Out:
# nullity: 487
#
# ---
# <class 'pandas.core.series.Series'>
# Index: 17272 entries, 0 to 7087
# Series name: HE_Uglu
# Non-Null Count  Dtype
# --------------  -----
# 16785 non-null  float64
# dtypes: float64(1)
# memory usage: 269.9 KB
#
# ---
# HE_Uglu
# 0.0    15825
# 5.0      332
# 1.0      287
# 4.0      147
# 2.0      110
# 3.0       84
# Name: count, dtype: int64

# %%
target_df = target_df.dropna().reset_index(drop=True)
target_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17272 entries, 0 to 17271
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   DE1_31    17272 non-null  float64
#  1   DE1_32    17272 non-null  float64
#  2   DE1_dg    17272 non-null  float64
#  3   HE_glu    17272 non-null  float64
#  4   HE_HbA1c  17272 non-null  float64
# dtypes: float64(5)
# memory usage: 674.8 KB

# %%
da_drug = []
for i, j in zip(df.DE1_31, df.DE1_32):
    if i == 1 or j == 1:
        da_drug.append(1)
    else:
        da_drug.append(0)
da_drug = np.array(da_drug)

target_df2 = target_df.copy()
target_df2['da_drug'] = da_drug
print(target_df2.head())
print(target_df2.info())
# Out:
#    DE1_31  DE1_32  DE1_dg  HE_glu  HE_HbA1c  da_drug
# 0     8.0     8.0     0.0   136.0       6.4        0
# 1     8.0     8.0     0.0    81.0       5.0        0
# 2     8.0     8.0     0.0    90.0       5.4        0
# 3     8.0     8.0     0.0    93.0       5.8        0
# 4     8.0     8.0     0.0   105.0       4.2        0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17272 entries, 0 to 17271
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   DE1_31    17272 non-null  float64
#  1   DE1_32    17272 non-null  float64
#  2   DE1_dg    17272 non-null  float64
#  3   HE_glu    17272 non-null  float64
#  4   HE_HbA1c  17272 non-null  float64
#  5   da_drug   17272 non-null  int32
# dtypes: float64(5), int32(1)
# memory usage: 742.3 KB
# None

# %%
target_df2['da_drug'].value_counts()
# Out:
# da_drug
# 0    15465
# 1     1807
# Name: count, dtype: int64

# %%
temp = ['sex','age', 'HE_insulin', 'HE_Uglu']
feature_df = df[temp]
feature_df.columns = ['sex','age', 'insulin', 'Urine glucose']
feature_df.sample(5,random_state=42)
# Out:
#       sex  age  insulin  Urine glucose
# 3557    2   65     15.1            5.0
# 3895    2   60      4.2            0.0
# 4723    1   78     18.6            0.0
# 5086    1   28      2.5            0.0
# 6307    1   71     18.7            0.0

# %%
#list 생성
diabetes = []
for i in range(len(target_df2)):
    if (target_df2.loc[i,'DE1_31']!=1) & (target_df2.loc[i,'DE1_32']!=1) & (target_df2.loc[i,'DE1_dg']!=1) & (target_df2.loc[i,'HE_glu']<126) & (target_df2.loc[i,'HE_HbA1c']<6.5):
        diabetes.append(0)
    else:
        diabetes.append(1)
diabetes = np.array(diabetes)
#column 추가
target_df = target_df2.copy()
target_df['diabetes'] = diabetes
target_df.sample(5,random_state=42)
# Out:
#        DE1_31  DE1_32  DE1_dg  HE_glu  HE_HbA1c  da_drug  diabetes
# 2714      0.0     1.0     1.0   135.0       7.1        1         1
# 9138      8.0     8.0     0.0    98.0       5.8        0         0
# 15428     0.0     1.0     1.0   141.0       7.0        1         1
# 15723     8.0     8.0     0.0    86.0       5.6        0         0
# 10947     8.0     8.0     0.0   115.0       5.9        0         0

# %%
df = df.drop(columns=target_list,axis=1)
df.shape
# Out:
# (17272, 28)

# %%
# 음주 정도
heavy_drink = []
for index, row in df.iterrows():
    if (row['sex'] == 1) & (row['BD1_11'] in [3, 4, 5, 6]) & (row['BD2_1'] in [4, 5]):
        heavy_drink.append(1)
    elif (row['sex'] == 2) & (row['BD1_11'] in [3, 4, 5, 6]) & (row['BD2_1'] in [3, 4, 5]):
        heavy_drink.append(1)
    else:
        heavy_drink.append(0)
heavy_drink = np.array(heavy_drink)
feature_df['heavy_drink'] = heavy_drink

# %%
# 현재흡연여부
df['sm_presnt'].replace({np.nan: 0}, inplace=True)
feature_df['smoke'] = df['sm_presnt'].astype(int)
feature_df.sample(5,random_state=42)
# Out:
# C:\Users\flinter\AppData\Local\Temp\ipykernel_31396\2788161982.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['sm_presnt'].replace({np.nan: 0}, inplace=True)
#       sex  age  insulin  Urine glucose  heavy_drink  smoke
# 3557    2   65     15.1            5.0            0      0
# 3895    2   60      4.2            0.0            0      0
# 4723    1   78     18.6            0.0            0      0
# 5086    1   28      2.5            0.0            0      0
# 6307    1   71     18.7            0.0            0      1

# %%
genetic = []
for index, row in df.iterrows():
    if (row['HE_DMfh1']==1) & (row['HE_DMfh2']==1):
        genetic.append(2)
    elif (row['HE_DMfh1']==1) & (row['HE_DMfh2']!=1):
        genetic.append(1)
    elif (row['HE_DMfh1']!=1) & (row['HE_DMfh2']==1):
        genetic.append(1)
    else:
        genetic.append(0)
genetic = np.array(genetic)
#column 추가
feature_df['genetic_diabetes'] = genetic
feature_df.sample(5,random_state=42)
# Out:
#       sex  age  insulin  Urine glucose  heavy_drink  smoke  genetic_diabetes
# 3557    2   65     15.1            5.0            0      0                 0
# 3895    2   60      4.2            0.0            0      0                 1
# 4723    1   78     18.6            0.0            0      0                 1
# 5086    1   28      2.5            0.0            0      0                 0
# 6307    1   71     18.7            0.0            0      1                 0

# %%
df['abdominal_obesity'] = ((df['sex'] == 1) & (df['HE_wc'] >= 90)) | ((df['sex'] == 2) & (df['HE_wc'] >= 85))
feature_df['abdominal_obesity'] = df['abdominal_obesity'].astype(int)
feature_df.sample(5,random_state=42)
# Out:
#       sex  age  insulin  Urine glucose  heavy_drink  smoke  genetic_diabetes  \
# 3557    2   65     15.1            5.0            0      0                 0
# 3895    2   60      4.2            0.0            0      0                 1
# 4723    1   78     18.6            0.0            0      0                 1
# 5086    1   28      2.5            0.0            0      0                 0
# 6307    1   71     18.7            0.0            0      1                 0
#
#       abdominal_obesity
# 3557                  1
# 3895                  0
# 4723                  1
# 5086                  0
# 6307                  0

# %%
see('HE_HTG')
# Out:
# nullity: 2740
#
# ---
# <class 'pandas.core.series.Series'>
# Index: 17272 entries, 0 to 7087
# Series name: HE_HTG
# Non-Null Count  Dtype
# --------------  -----
# 14532 non-null  float64
# dtypes: float64(1)
# memory usage: 269.9 KB
#
# ---
# HE_HTG
# 0.0    12668
# 1.0     1864
# Name: count, dtype: int64

# %%
feature_df['Hypercholesterolemia'] = df['HE_HCHOL'].astype('Int64')
feature_df['hypertriglyceridemia'] = df['HE_HTG'].astype('Int64')
feature_df['high_bloodpressure'] = df['HE_HP'].astype('Int64')
feature_df.replace(pd.NA, np.nan, inplace=True)
# 결과 확인
feature_df.sample(5, random_state=42)
# Out:
#       sex  age  insulin  Urine glucose  heavy_drink  smoke  genetic_diabetes  \
# 3557    2   65     15.1            5.0            0      0                 0
# 3895    2   60      4.2            0.0            0      0                 1
# 4723    1   78     18.6            0.0            0      0                 1
# 5086    1   28      2.5            0.0            0      0                 0
# 6307    1   71     18.7            0.0            0      1                 0
#
#       abdominal_obesity  Hypercholesterolemia  hypertriglyceridemia  \
# 3557                  1                     1                     1
# 3895                  0                     0                     0
# 4723                  1                     1                     1
# 5086                  0                     0                  <NA>
# 6307                  0                     0                     0
#
#       high_bloodpressure
# 3557                   3
# 3895                   1
# 4723                   3
# 5086                   1
# 6307                   2

# %%
# 뇌졸중
feature_df['stroke'] = df['DI3_dg'].replace({9: np.nan}).astype("Int64")
# 심근경색증
feature_df['myocardial_infarction'] = df['DI5_dg'].replace({9: np.nan}).astype('Int64')
feature_df.sample(5, random_state=42)
# Out:
#       sex  age  insulin  Urine glucose  heavy_drink  smoke  genetic_diabetes  \
# 3557    2   65     15.1            5.0            0      0                 0
# 3895    2   60      4.2            0.0            0      0                 1
# 4723    1   78     18.6            0.0            0      0                 1
# 5086    1   28      2.5            0.0            0      0                 0
# 6307    1   71     18.7            0.0            0      1                 0
#
#       abdominal_obesity  Hypercholesterolemia  hypertriglyceridemia  \
# 3557                  1                     1                     1
# 3895                  0                     0                     0
# 4723                  1                     1                     1
# 5086                  0                     0                  <NA>
# 6307                  0                     0                     0
#
#       high_bloodpressure  stroke  myocardial_infarction
# 3557                   3       1                      0
# 3895                   1       0                      0
# 4723                   3       0                      0
# 5086                   1       0                      0
# 6307                   2       0                      0

# %%
# 체중, BMI
exam_list0 = ['HE_wt','HE_BMI']
exam_list1 = ['weight','BMI']

feature_df[exam_list1] = df[exam_list0].astype(float)
feature_df.sample(5,random_state=42)
# Out:
#       sex  age  insulin  Urine glucose  heavy_drink  smoke  genetic_diabetes  \
# 3557    2   65     15.1            5.0            0      0                 0
# 3895    2   60      4.2            0.0            0      0                 1
# 4723    1   78     18.6            0.0            0      0                 1
# 5086    1   28      2.5            0.0            0      0                 0
# 6307    1   71     18.7            0.0            0      1                 0
#
#       abdominal_obesity  Hypercholesterolemia  hypertriglyceridemia  \
# 3557                  1                     1                     1
# 3895                  0                     0                     0
# 4723                  1                     1                     1
# 5086                  0                     0                  <NA>
# 6307                  0                     0                     0
#
#       high_bloodpressure  stroke  myocardial_infarction  weight        BMI
# 3557                   3       1                      0    63.3  24.944348
# 3895                   1       0                      0    47.8  18.718642
# 4723                   3       0                      0    68.8  27.840905
# 5086                   1       0                      0    55.3  18.328440
# 6307                   2       0                      0    58.1  22.165750

# %%
#비만도
feature_df['Obesity'] = df['HE_obe'].astype('Int64')
feature_df.sample(5,random_state=42)
# Out:
#       sex  age  insulin  Urine glucose  heavy_drink  smoke  genetic_diabetes  \
# 3557    2   65     15.1            5.0            0      0                 0
# 3895    2   60      4.2            0.0            0      0                 1
# 4723    1   78     18.6            0.0            0      0                 1
# 5086    1   28      2.5            0.0            0      0                 0
# 6307    1   71     18.7            0.0            0      1                 0
#
#       abdominal_obesity  Hypercholesterolemia  hypertriglyceridemia  \
# 3557                  1                     1                     1
# 3895                  0                     0                     0
# 4723                  1                     1                     1
# 5086                  0                     0                  <NA>
# 6307                  0                     0                     0
#
#       high_bloodpressure  stroke  myocardial_infarction  weight        BMI  \
# 3557                   3       1                      0    63.3  24.944348
# 3895                   1       0                      0    47.8  18.718642
# 4723                   3       0                      0    68.8  27.840905
# 5086                   1       0                      0    55.3  18.328440
# 6307                   2       0                      0    58.1  22.165750
#
#       Obesity
# 3557        3
# 3895        2
# 4723        4
# 5086        1
# 6307        2

# %%
feature_df['stroke'].value_counts()
# Out:
# stroke
# 0    15830
# 1      374
# Name: count, dtype: Int64

# %%
def walking_practice(row):
    # '88', '99'를 가지고 있는 경우는 null로 처리
    if row['BE3_31'] in [88, 99] or row['BE3_32'] in [88, 99] or row['BE3_33'] in [88, 99]:
        return np.nan
    # BE3_31(걷기 일수)가 5 이상이고, BE3_32(걷기 지속 시간(시간))이 1 이상이거나 BE3_33(걷기 지속 시간(분))이 30 이상인 경우 걷기 실천으로 판단
    elif row['BE3_31'] >= 5 and (row['BE3_32'] >= 1 or row['BE3_33'] >= 30):
        return 1
    else:
        return 0

feature_df['walking_practice'] = df.apply(walking_practice, axis=1).astype('Int64')
feature_df.sample(5,random_state=42)
# Out:
#       sex  age  insulin  Urine glucose  heavy_drink  smoke  genetic_diabetes  \
# 3557    2   65     15.1            5.0            0      0                 0
# 3895    2   60      4.2            0.0            0      0                 1
# 4723    1   78     18.6            0.0            0      0                 1
# 5086    1   28      2.5            0.0            0      0                 0
# 6307    1   71     18.7            0.0            0      1                 0
#
#       abdominal_obesity  Hypercholesterolemia  hypertriglyceridemia  \
# 3557                  1                     1                     1
# 3895                  0                     0                     0
# 4723                  1                     1                     1
# 5086                  0                     0                  <NA>
# 6307                  0                     0                     0
#
#       high_bloodpressure  stroke  myocardial_infarction  weight        BMI  \
# 3557                   3       1                      0    63.3  24.944348
# 3895                   1       0                      0    47.8  18.718642
# 4723                   3       0                      0    68.8  27.840905
# 5086                   1       0                      0    55.3  18.328440
# 6307                   2       0                      0    58.1  22.165750
#
#       Obesity  walking_practice
# 3557        3                 1
# 3895        2                 0
# 4723        4                 0
# 5086        1                 1
# 6307        2                 1

# %%
float_data = [
    'age',
    'weight',
    'BMI',
    'N_EN',
    'N_PROT', 
    'N_FAT', 
    'N_CHO',
    'insulin'
]

# %%
feature_df[['N_EN', 'N_PROT', 'N_FAT', 'N_CHO']] = df[['N_EN', 'N_PROT', 'N_FAT', 'N_CHO']]

# %%
feature_df['diabetes'] = target_df['diabetes']
feature_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17272 entries, 0 to 7087
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   sex                    17272 non-null  int64
#  1   age                    17272 non-null  int64
#  2   insulin                17266 non-null  float64
#  3   Urine glucose          16785 non-null  float64
#  4   heavy_drink            17272 non-null  int32
#  5   smoke                  17272 non-null  int32
#  6   genetic_diabetes       17272 non-null  int32
#  7   abdominal_obesity      17272 non-null  int32
#  8   Hypercholesterolemia   16754 non-null  Int64
#  9   hypertriglyceridemia   14532 non-null  Int64
#  10  high_bloodpressure     17081 non-null  Int64
#  11  stroke                 16204 non-null  Int64
#  12  myocardial_infarction  16196 non-null  Int64
#  13  weight                 17212 non-null  float64
#  14  BMI                    17063 non-null  float64
#  15  Obesity                17030 non-null  Int64
#  16  walking_practice       13273 non-null  Int64
#  17  N_EN                   14309 non-null  float64
#  18  N_PROT                 14309 non-null  float64
#  19  N_FAT                  14309 non-null  float64
#  20  N_CHO                  14309 non-null  float64
#  21  diabetes               17272 non-null  int32
# dtypes: Int64(7), float64(8), int32(5), int64(2)
# memory usage: 2.8 MB

# %%
y = feature_df.diabetes
X = feature_df.drop('diabetes', axis=1)

# Replace empty strings with NaN
feature_df.replace('', float('nan'), inplace=True)

# Initialize and fit KNNImputer
knn = KNNImputer(n_neighbors=5, weights="uniform")
k_df = pd.DataFrame(knn.fit_transform(feature_df), columns=feature_df.columns)

# 각 열의 데이터 타입을 변환
for col in k_df.columns:
    if col in float_data:
        k_df[col] = k_df[col].astype(float)
    else:
        k_df[col] = k_df[col].astype(int)
        k_df[col] = k_df[col].astype('category')

# %%
feature_df = k_df.copy()

# %%
feature_df.isnull().sum()
# Out:
# sex                      0
# age                      0
# insulin                  0
# Urine glucose            0
# heavy_drink              0
# smoke                    0
# genetic_diabetes         0
# abdominal_obesity        0
# Hypercholesterolemia     0
# hypertriglyceridemia     0
# high_bloodpressure       0
# stroke                   0
# myocardial_infarction    0
# weight                   0
# BMI                      0
# Obesity                  0
# walking_practice         0
# N_EN                     0
# N_PROT                   0
# N_FAT                    0
# N_CHO                    0
# diabetes                 0
# dtype: int64

# %%
feature_df.info()

# %%
feature_df.head()
# Out:
#   sex   age  insulin Urine glucose heavy_drink smoke genetic_diabetes  \
# 0   1  61.0     10.4             4           1     0                0
# 1   1  28.0      2.3             0           0     0                0
# 2   1  53.0      1.4             0           1     1                0
# 3   2  50.0      6.6             0           0     0                0
# 4   2  71.0      5.0             0           0     0                0
#
#   abdominal_obesity Hypercholesterolemia hypertriglyceridemia  ...  \
# 0                 1                    0                    0  ...
# 1                 0                    0                    0  ...
# 2                 0                    0                    0  ...
# 3                 0                    0                    0  ...
# 4                 1                    0                    0  ...
#
#   myocardial_infarction weight        BMI  Obesity  walking_practice  \
# 0                     0   81.6  25.987394        4                 0
# 1                     0   51.7  16.900942        1                 0
# 2                     0   63.1  19.781829        2                 0
# 3                     0   63.9  26.631647        4                 0
# 4                     0   63.6  29.312416        4                 0
#
#           N_EN     N_PROT      N_FAT       N_CHO  diabetes
# 0  1901.443968  70.236597  30.048061  243.097700         1
# 1  2103.451898  89.197144  59.449590  306.493959         0
# 2  1794.462141  73.011520  33.617174  295.234107         0
# 3  1921.973206  82.134681  60.321382  258.768545         0
# 4  1948.473145  81.044523  68.819501  255.163743         0
#
# [5 rows x 22 columns]

# %%
# 에너지 섭취 분율 계산 함수
def calculate_energy_ratio(row):
    # 에너지 섭취량 계산
    energy_intake = (row['N_PROT'] * 4) + (row['N_FAT'] * 9) + (row['N_CHO'] * 4)
    
    # 단백질, 지방, 탄수화물 에너지 섭취 분율 계산
    protein_energy_ratio = (row['N_PROT'] * 4) / energy_intake if energy_intake != 0 else 0
    fat_energy_ratio = (row['N_FAT'] * 9) / energy_intake if energy_intake != 0 else 0
    carbohydrate_energy_ratio = (row['N_CHO'] * 4) / energy_intake if energy_intake != 0 else 0
    
    return protein_energy_ratio, fat_energy_ratio, carbohydrate_energy_ratio

# 에너지 섭취 분율 계산하여 새로운 열로 추가
feature_df['protein_energy_ratio'], feature_df['fat_energy_ratio'], feature_df['carbohydrate_energy_ratio'] = zip(*feature_df.apply(calculate_energy_ratio, axis=1))
feature_df['energy'] = feature_df['N_EN']
feature_df.drop(columns=['N_EN', 'N_PROT', 'N_FAT', 'N_CHO'], inplace=True)
feature_df.sample(5,random_state=42)
# Out:
#       sex   age  insulin Urine glucose heavy_drink smoke genetic_diabetes  \
# 2714    2  65.0     15.1             5           0     0                0
# 9138    2  60.0      4.2             0           0     0                1
# 15428   1  78.0     18.6             0           0     0                1
# 15723   1  28.0      2.5             0           0     0                0
# 10947   1  71.0     18.7             0           0     1                0
#
#       abdominal_obesity Hypercholesterolemia hypertriglyceridemia  ...  \
# 2714                  1                    1                    1  ...
# 9138                  0                    0                    0  ...
# 15428                 1                    1                    1  ...
# 15723                 0                    0                    0  ...
# 10947                 0                    0                    0  ...
#
#       myocardial_infarction weight        BMI  Obesity  walking_practice  \
# 2714                      0   63.3  24.944348        3                 1
# 9138                      0   47.8  18.718642        2                 0
# 15428                     0   68.8  27.840905        4                 0
# 15723                     0   55.3  18.328440        1                 1
# 10947                     0   58.1  22.165750        2                 1
#
#       diabetes protein_energy_ratio fat_energy_ratio  \
# 2714         0             0.089157         0.115973
# 9138         0             0.099846         0.282981
# 15428        0             0.099629         0.078991
# 15723        0             0.171826         0.332794
# 10947        0             0.098941         0.063204
#
#        carbohydrate_energy_ratio       energy
# 2714                    0.794869  1562.371480
# 9138                    0.617174   821.629000
# 15428                   0.821380  1477.274000
# 15723                   0.495379  2193.326329
# 10947                   0.837855  1213.372152
#
# [5 rows x 22 columns]

# %%
feature_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17272 entries, 0 to 17271
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   sex                        17272 non-null  category
#  1   age                        17272 non-null  float64
#  2   insulin                    17272 non-null  float64
#  3   Urine glucose              17272 non-null  category
#  4   heavy_drink                17272 non-null  category
#  5   smoke                      17272 non-null  category
#  6   genetic_diabetes           17272 non-null  category
#  7   abdominal_obesity          17272 non-null  category
#  8   Hypercholesterolemia       17272 non-null  category
#  9   hypertriglyceridemia       17272 non-null  category
#  10  high_bloodpressure         17272 non-null  category
#  11  stroke                     17272 non-null  category
#  12  myocardial_infarction      17272 non-null  category
#  13  weight                     17272 non-null  float64
#  14  BMI                        17272 non-null  float64
#  15  Obesity                    17272 non-null  category
#  16  walking_practice           17272 non-null  category
#  17  diabetes                   17272 non-null  category
#  18  protein_energy_ratio       17272 non-null  float64
#  19  fat_energy_ratio           17272 non-null  float64
#  20  carbohydrate_energy_ratio  17272 non-null  float64
#  21  energy                     17272 non-null  float64
# dtypes: category(14), float64(8)
# memory usage: 1.3 MB

# %%
# # 프로파일링 보고서 생성
# profile = ProfileReport(feature_df, title="Profiling Report")
# # 보고서 저장 (선택사항)
# profile.to_file("../resources/Profiling Report_small.html")

# %%
feature_df.drop(['diabetes'], axis=1, inplace=True)
feature_df['diabetes'] = target_df['diabetes'].astype('category')
feature_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17272 entries, 0 to 17271
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   sex                        17272 non-null  category
#  1   age                        17272 non-null  float64
#  2   insulin                    17272 non-null  float64
#  3   Urine glucose              17272 non-null  category
#  4   heavy_drink                17272 non-null  category
#  5   smoke                      17272 non-null  category
#  6   genetic_diabetes           17272 non-null  category
#  7   abdominal_obesity          17272 non-null  category
#  8   Hypercholesterolemia       17272 non-null  category
#  9   hypertriglyceridemia       17272 non-null  category
#  10  high_bloodpressure         17272 non-null  category
#  11  stroke                     17272 non-null  category
#  12  myocardial_infarction      17272 non-null  category
#  13  weight                     17272 non-null  float64
#  14  BMI                        17272 non-null  float64
#  15  Obesity                    17272 non-null  category
#  16  walking_practice           17272 non-null  category
#  17  protein_energy_ratio       17272 non-null  float64
#  18  fat_energy_ratio           17272 non-null  float64
#  19  carbohydrate_energy_ratio  17272 non-null  float64
#  20  energy                     17272 non-null  float64
#  21  diabetes                   17272 non-null  category
# dtypes: category(14), float64(8)
# memory usage: 1.3 MB

# %%
feature_df.to_csv("../data/data_small.csv", index=False)

# %%
corr0 = feature_df.corr(method='pearson')
corr0.iloc[0:,-1:].style.background_gradient(cmap='coolwarm',vmin=-1,vmax=1)
# Out:
# <style type="text/css">
# #T_00f1d_row0_col0, #T_00f1d_row17_col0 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_00f1d_row1_col0 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_00f1d_row2_col0, #T_00f1d_row15_col0 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_00f1d_row3_col0 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_00f1d_row4_col0 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_00f1d_row5_col0 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_00f1d_row6_col0, #T_00f1d_row11_col0, #T_00f1d_row13_col0 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_00f1d_row7_col0 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_00f1d_row8_col0 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_00f1d_row9_col0 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_00f1d_row10_col0 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_00f1d_row12_col0 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_00f1d_row14_col0 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_00f1d_row16_col0 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_00f1d_row18_col0 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_00f1d_row19_col0 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_00f1d_row20_col0 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_00f1d_row21_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_00f1d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_00f1d_level0_col0" class="col_heading level0 col0" >diabetes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_00f1d_level0_row0" class="row_heading level0 row0" >sex</th>
#       <td id="T_00f1d_row0_col0" class="data row0 col0" >-0.057012</td>
#     </tr>
#     <tr>
#       <th id="T_00f1d_level0_row1" class="row_heading level0 row1" >age</th>
#       <td id="T_00f1d_row1_col0" class="data row1 col0" >0.298086</td>
#     </tr>
#     <tr>
#       <th id="T_00f1d_level0_row2" class="row_heading level0 row2" >insulin</th>
#       <td id="T_00f1d_row2_col0" class="data row2 col0" >0.164959</td>
#     </tr>
#     <tr>
#       <th id="T_00f1d_level0_row3" class="row_heading level0 row3" >Urine glucose</th>
#       <td id="T_00f1d_row3_col0" class="data row3 col0" >0.426171</td>
#     </tr>
#     <tr>
#       <th id="T_00f1d_level0_row4" class="row_heading level0 row4" >heavy_drink</th>
#       <td id="T_00f1d_row4_col0" class="data row4 col0" >-0.037715</td>
#     </tr>
#     <tr>
#       <th id="T_00f1d_level0_row5" class="row_heading level0 row5" >smoke</th>
#       <td id="T_00f1d_row5_col0" class="data row5 col0" >0.015603</td>
#     </tr>
#     <tr>
#       <th id="T_00f1d_level0_row6" class="row_heading level0 row6" >genetic_diabetes</th>
#       <td id="T_00f1d_row6_col0" class="data row6 col0" >0.078584</td>
#     </tr>
#     <tr>
#       <th id="T_00f1d_level0_row7" class="row_heading level0 row7" >abdominal_obesity</th>
#       <td id="T_00f1d_row7_col0" class="data row7 col0" >0.219633</td>
#     </tr>
#     <tr>
#       <th id="T_00f1d_level0_row8" class="row_heading level0 row8" >Hypercholesterolemia</th>
#       <td id="T_00f1d_row8_col0" class="data row8 col0" >0.199851</td>
#     </tr>
#     <tr>
#       <th id="T_00f1d_level0_row9" class="row_heading level0 row9" >hypertriglyceridemia</th>
#       <td id="T_00f1d_row9_col0" class="data row9 col0" >0.075488</td>
#     </tr>
#     <tr>
#       <th id="T_00f1d_level0_row10" class="row_heading level0 row10" >high_bloodpressure</th>
#       <td id="T_00f1d_row10_col0" class="data row10 col0" >0.258819</td>
#     </tr>
#     <tr>
#       <th id="T_00f1d_level0_row11" class="row_heading level0 row11" >stroke</th>
#       <td id="T_00f1d_row11_col0" class="data row11 col0" >0.083350</td>
#     </tr>
#     <tr>
#       <th id="T_00f1d_level0_row12" class="row_heading level0 row12" >myocardial_infarction</th>
#       <td id="T_00f1d_row12_col0" class="data row12 col0" >0.089300</td>
#     </tr>
#     <tr>
#       <th id="T_00f1d_level0_row13" class="row_heading level0 row13" >weight</th>
#       <td id="T_00f1d_row13_col0" class="data row13 col0" >0.079333</td>
#     </tr>
#     <tr>
#       <th id="T_00f1d_level0_row14" class="row_heading level0 row14" >BMI</th>
#       <td id="T_00f1d_row14_col0" class="data row14 col0" >0.173814</td>
#     </tr>
#     <tr>
#       <th id="T_00f1d_level0_row15" class="row_heading level0 row15" >Obesity</th>
#       <td id="T_00f1d_row15_col0" class="data row15 col0" >0.168803</td>
#     </tr>
#     <tr>
#       <th id="T_00f1d_level0_row16" class="row_heading level0 row16" >walking_practice</th>
#       <td id="T_00f1d_row16_col0" class="data row16 col0" >-0.025238</td>
#     </tr>
#     <tr>
#       <th id="T_00f1d_level0_row17" class="row_heading level0 row17" >protein_energy_ratio</th>
#       <td id="T_00f1d_row17_col0" class="data row17 col0" >-0.060887</td>
#     </tr>
#     <tr>
#       <th id="T_00f1d_level0_row18" class="row_heading level0 row18" >fat_energy_ratio</th>
#       <td id="T_00f1d_row18_col0" class="data row18 col0" >-0.162772</td>
#     </tr>
#     <tr>
#       <th id="T_00f1d_level0_row19" class="row_heading level0 row19" >carbohydrate_energy_ratio</th>
#       <td id="T_00f1d_row19_col0" class="data row19 col0" >0.157387</td>
#     </tr>
#     <tr>
#       <th id="T_00f1d_level0_row20" class="row_heading level0 row20" >energy</th>
#       <td id="T_00f1d_row20_col0" class="data row20 col0" >-0.054575</td>
#     </tr>
#     <tr>
#       <th id="T_00f1d_level0_row21" class="row_heading level0 row21" >diabetes</th>
#       <td id="T_00f1d_row21_col0" class="data row21 col0" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
y = feature_df.diabetes
X = feature_df.drop('diabetes', axis=1)

# 히트맵 그리기
plt.figure(figsize=(15, 15))
mask = np.triu(np.ones_like(X.corr(), dtype=bool))
sns.heatmap(X.corr(), annot=True)
plt.savefig('../resources/heatmap_small.png')
plt.show()

# %%
feature_df.drop(['myocardial_infarction', 'weight', 'Obesity'], axis=1, inplace=True)

# %%
corr0 = feature_df.corr(method='pearson')
corr0.iloc[0:,-1:].style.background_gradient(cmap='coolwarm',vmin=-1,vmax=1)
# Out:
# <style type="text/css">
# #T_bd4a4_row0_col0, #T_bd4a4_row14_col0 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_bd4a4_row1_col0 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_bd4a4_row2_col0 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_bd4a4_row3_col0 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_bd4a4_row4_col0 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_bd4a4_row5_col0 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_bd4a4_row6_col0, #T_bd4a4_row11_col0 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_bd4a4_row7_col0 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_bd4a4_row8_col0 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_bd4a4_row9_col0 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_bd4a4_row10_col0 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_bd4a4_row12_col0 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_bd4a4_row13_col0 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_bd4a4_row15_col0 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_bd4a4_row16_col0 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_bd4a4_row17_col0 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_bd4a4_row18_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_bd4a4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bd4a4_level0_col0" class="col_heading level0 col0" >diabetes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bd4a4_level0_row0" class="row_heading level0 row0" >sex</th>
#       <td id="T_bd4a4_row0_col0" class="data row0 col0" >-0.057012</td>
#     </tr>
#     <tr>
#       <th id="T_bd4a4_level0_row1" class="row_heading level0 row1" >age</th>
#       <td id="T_bd4a4_row1_col0" class="data row1 col0" >0.298086</td>
#     </tr>
#     <tr>
#       <th id="T_bd4a4_level0_row2" class="row_heading level0 row2" >insulin</th>
#       <td id="T_bd4a4_row2_col0" class="data row2 col0" >0.164959</td>
#     </tr>
#     <tr>
#       <th id="T_bd4a4_level0_row3" class="row_heading level0 row3" >Urine glucose</th>
#       <td id="T_bd4a4_row3_col0" class="data row3 col0" >0.426171</td>
#     </tr>
#     <tr>
#       <th id="T_bd4a4_level0_row4" class="row_heading level0 row4" >heavy_drink</th>
#       <td id="T_bd4a4_row4_col0" class="data row4 col0" >-0.037715</td>
#     </tr>
#     <tr>
#       <th id="T_bd4a4_level0_row5" class="row_heading level0 row5" >smoke</th>
#       <td id="T_bd4a4_row5_col0" class="data row5 col0" >0.015603</td>
#     </tr>
#     <tr>
#       <th id="T_bd4a4_level0_row6" class="row_heading level0 row6" >genetic_diabetes</th>
#       <td id="T_bd4a4_row6_col0" class="data row6 col0" >0.078584</td>
#     </tr>
#     <tr>
#       <th id="T_bd4a4_level0_row7" class="row_heading level0 row7" >abdominal_obesity</th>
#       <td id="T_bd4a4_row7_col0" class="data row7 col0" >0.219633</td>
#     </tr>
#     <tr>
#       <th id="T_bd4a4_level0_row8" class="row_heading level0 row8" >Hypercholesterolemia</th>
#       <td id="T_bd4a4_row8_col0" class="data row8 col0" >0.199851</td>
#     </tr>
#     <tr>
#       <th id="T_bd4a4_level0_row9" class="row_heading level0 row9" >hypertriglyceridemia</th>
#       <td id="T_bd4a4_row9_col0" class="data row9 col0" >0.075488</td>
#     </tr>
#     <tr>
#       <th id="T_bd4a4_level0_row10" class="row_heading level0 row10" >high_bloodpressure</th>
#       <td id="T_bd4a4_row10_col0" class="data row10 col0" >0.258819</td>
#     </tr>
#     <tr>
#       <th id="T_bd4a4_level0_row11" class="row_heading level0 row11" >stroke</th>
#       <td id="T_bd4a4_row11_col0" class="data row11 col0" >0.083350</td>
#     </tr>
#     <tr>
#       <th id="T_bd4a4_level0_row12" class="row_heading level0 row12" >BMI</th>
#       <td id="T_bd4a4_row12_col0" class="data row12 col0" >0.173814</td>
#     </tr>
#     <tr>
#       <th id="T_bd4a4_level0_row13" class="row_heading level0 row13" >walking_practice</th>
#       <td id="T_bd4a4_row13_col0" class="data row13 col0" >-0.025238</td>
#     </tr>
#     <tr>
#       <th id="T_bd4a4_level0_row14" class="row_heading level0 row14" >protein_energy_ratio</th>
#       <td id="T_bd4a4_row14_col0" class="data row14 col0" >-0.060887</td>
#     </tr>
#     <tr>
#       <th id="T_bd4a4_level0_row15" class="row_heading level0 row15" >fat_energy_ratio</th>
#       <td id="T_bd4a4_row15_col0" class="data row15 col0" >-0.162772</td>
#     </tr>
#     <tr>
#       <th id="T_bd4a4_level0_row16" class="row_heading level0 row16" >carbohydrate_energy_ratio</th>
#       <td id="T_bd4a4_row16_col0" class="data row16 col0" >0.157387</td>
#     </tr>
#     <tr>
#       <th id="T_bd4a4_level0_row17" class="row_heading level0 row17" >energy</th>
#       <td id="T_bd4a4_row17_col0" class="data row17 col0" >-0.054575</td>
#     </tr>
#     <tr>
#       <th id="T_bd4a4_level0_row18" class="row_heading level0 row18" >diabetes</th>
#       <td id="T_bd4a4_row18_col0" class="data row18 col0" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
y = feature_df.diabetes
X = feature_df.drop('diabetes', axis=1)

# 히트맵 그리기
plt.figure(figsize=(15, 15))
mask = np.triu(np.ones_like(X.corr(), dtype=bool))
sns.heatmap(X.corr(), annot=True)
plt.savefig('../resources/heatmap_small_repair.png')
plt.show()

# %%
feature_df.to_csv("../data/data_small.csv", index=False)

# %%
feature_df['diabetes'].value_counts()
# Out:
# diabetes
# 0    14437
# 1     2835
# Name: count, dtype: int64

# %%
# # 프로파일링 보고서 생성
# profile = ProfileReport(feature_df, title="Profiling Report")
# # 보고서 저장 (선택사항)
# profile.to_file("../resources/Profiling Report_small.html")

# %%
feature_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17272 entries, 0 to 17271
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   sex                        17272 non-null  category
#  1   age                        17272 non-null  float64
#  2   insulin                    17272 non-null  float64
#  3   Urine glucose              17272 non-null  category
#  4   heavy_drink                17272 non-null  category
#  5   smoke                      17272 non-null  category
#  6   genetic_diabetes           17272 non-null  category
#  7   abdominal_obesity          17272 non-null  category
#  8   Hypercholesterolemia       17272 non-null  category
#  9   hypertriglyceridemia       17272 non-null  category
#  10  high_bloodpressure         17272 non-null  category
#  11  stroke                     17272 non-null  category
#  12  BMI                        17272 non-null  float64
#  13  walking_practice           17272 non-null  category
#  14  protein_energy_ratio       17272 non-null  float64
#  15  fat_energy_ratio           17272 non-null  float64
#  16  carbohydrate_energy_ratio  17272 non-null  float64
#  17  energy                     17272 non-null  float64
#  18  diabetes                   17272 non-null  category
# dtypes: category(12), float64(7)
# memory usage: 1.1 MB

# %%
feature_df.head()
# Out:
#   sex   age  insulin Urine glucose heavy_drink smoke genetic_diabetes  \
# 0   1  61.0     10.4             4           1     0                0
# 1   1  28.0      2.3             0           0     0                0
# 2   1  53.0      1.4             0           1     1                0
# 3   2  50.0      6.6             0           0     0                0
# 4   2  71.0      5.0             0           0     0                0
#
#   abdominal_obesity Hypercholesterolemia hypertriglyceridemia  \
# 0                 1                    0                    0
# 1                 0                    0                    0
# 2                 0                    0                    0
# 3                 0                    0                    0
# 4                 1                    0                    0
#
#   high_bloodpressure stroke        BMI walking_practice  protein_energy_ratio  \
# 0                  3      0  25.987394                0              0.184376
# 1                  1      0  16.900942                0              0.168470
# 2                  2      0  19.781829                0              0.164483
# 3                  1      0  26.631647                0              0.172325
# 4                  3      0  29.312416                0              0.165043
#
#    fat_energy_ratio  carbohydrate_energy_ratio       energy diabetes
# 0          0.177476                   0.638148  1901.443968        1
# 1          0.252641                   0.578888  2103.451898        0
# 2          0.170402                   0.665115  1794.462141        0
# 3          0.284758                   0.542917  1921.973206        0
# 4          0.315331                   0.519627  1948.473145        0

# %% [markdown]
# - 당뇨병: 공복혈당이 126 mg/dL 이상이거나 의사로부터 당뇨병을 진단받았거나 당뇨병약제로 치료 중이거나 당화혈색소가 6.5% 이상
#
# - 조절 불가 위험요인
# •나이
# •성별
# •가족력(당뇨병)
#
# - 만성질환 위험요인
# •고혈압: 수축기혈압이 140 mmHg 이상이거나 이완기혈압이 90 mmHg 이상 또는 고혈압약제를 복용
# •고콜레스테롤혈증: LDL 콜레스테롤이 100 mg/dL 이상이거나 콜레스테롤강하제를 복용
# •낮은 HDL 콜레스테롤: 남자 ＜ 40 mg/dL, 여자 ＜ 50 mg/dL 또는 이상지질혈증약 복용
# •심혈관질환(뇌졸중, 관상동맥질환 등)
#
# - 생활습관 위험요인
# - 비만: ➀ <18.5 저체중 ➁ 18.5-22.9 정상체중 ➂ 23.0-24.9 비만전단계 ➃ 25.0-29.9 1단계 비만 ➄ 30.0-34.9 2단계 비만 ➅ 35.0 이상 3단계 비만
# - 복부비만(허리둘레 기준): 남자 90 cm 이상, 여자 85 cm 이상인 경우
# - 흡연:
# •현재흡연: 평생 총 5갑(100개비)이상의 담배를 피웠으며 현재도 담배를 피우고 있는 경우
# •과거흡연: 평생 총 5갑(100개비)이상의 담배를 피웠으나 현재는 담배를 피우지 않는 경우
# •비흡연: 평생 총 5갑(100개비)이상의 담배를 피운 적이 없는 경우
#
# - 음주:  1회 평균 음주량이 남자 7잔, 여자 5잔 이상이며, 주 2회 이상 음주하는 분
# - 운동(걷기 실천률): 최근 1주일 동안 걷기를 1일 총 30분 이상, 주 5일 이상 실천
#
# - 에너지 과잉 섭취 분율: 에너지 섭취량이 필요추정량의 125% 이상인 분율
# - 단백질 에너지 섭취 분율: {(단백질 섭취량×4)+(지방 섭취량×9)+(탄수화물 섭취량×4)}에 대한(단백질 섭취량×4)의 분율
# - 지방 에너지 섭취 분율: {(단백질 섭취량×4)+(지방 섭취량×9)+(탄수화물 섭취량×4)}에 대한(지방 섭취량×9)의 분율
# - 탄수화물 에너지 섭취 분율: {(단백질 섭취량×4)+(지방 섭취량×9)+(탄수화물 섭취량×4)}에 대한(탄수화물 섭취량×4)의 분율
